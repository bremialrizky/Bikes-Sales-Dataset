# %%
#import csv ke pandas
import pandas as pd

df = pd.read_csv(r'D:\Bahan Belajar\Project\Bike Sales\Sales.csv')

df
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
# 113032  2014-04-02    2     April  2014            18     Youth (<25)
# 113033  2016-04-02    2     April  2016            18     Youth (<25)
# 113034  2014-03-04    4     March  2014            37  Adults (35-64)
# 113035  2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
#Cari data duplikat
#Sort nilai dari tanggal
#Cek nilai Gender apa saja
#Cek apakah data day month year sesuai dengan date
#Cek apakah data cst age sesuai dengan kriteria age group
#Tambah Kolom Nama Hari

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  object
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
#df['Day_Name'] = df['Date'].dt.day_name()

# Tambahkan kolom baru di posisi setelah 'date'
pos = df.columns.get_loc('Date') + 1  # posisi setelah 'date'
df.insert(pos, 'Day_Name', df['Date'].dt.day_name())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  datetime64[ns]
#  1   Day_Name          113036 non-null  object
#  2   Day               113036 non-null  int64
#  3   Month             113036 non-null  object
#  4   Year              113036 non-null  int64
#  5   Customer_Age      113036 non-null  int64
#  6   Age_Group         113036 non-null  object
#  7   Customer_Gender   113036 non-null  object
#  8   Country           113036 non-null  object
#  9   State             113036 non-null  object
#  10  Product_Category  113036 non-null  object
#  11  Sub_Category      113036 non-null  object
#  12  Product           113036 non-null  object
#  13  Order_Quantity    113036 non-null  int64
#  14  Unit_Cost         113036 non-null  int64
#  15  Unit_Price        113036 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# Date                0
# Day_Name            0
# Day                 0
# Month               0
# Year                0
# Customer_Age        0
# Age_Group           0
# Customer_Gender     0
# Country             0
# State               0
# Product_Category    0
# Sub_Category        0
# Product             0
# Order_Quantity      0
# Unit_Cost           0
# Unit_Price          0
# Profit              0
# Cost                0
# Revenue             0
# dtype: int64

# %%
#urutan_bulan = [
 #   'January', 'February', 'March', 'April', 'May', 'June',
  #  'July', 'August', 'September', 'October', 'November', 'December'
#]

#df['Month'] = pd.Categorical(df['Month'], categories=urutan_bulan, ordered=True)

#df = df.sort_values(by=['Year', 'Month'])
#df

# %%
df = df.sort_values(by='Date')
df
# Out:
#             Date  Day_Name  Day    Month  Year  Customer_Age  \
# 60993 2011-01-01  Saturday    1  January  2011            42
# 58729 2011-01-01  Saturday    1  January  2011            33
# 58913 2011-01-01  Saturday    1  January  2011            17
# 63711 2011-01-01  Saturday    1  January  2011            39
# 49787 2011-01-01  Saturday    1  January  2011            23
# ...          ...       ...  ...      ...   ...           ...
# 22465 2016-07-31    Sunday   31     July  2016            39
# 23363 2016-07-31    Sunday   31     July  2016            39
# 19225 2016-07-31    Sunday   31     July  2016            48
# 94147 2016-07-31    Sunday   31     July  2016            51
# 80944 2016-07-31    Sunday   31     July  2016            42
#
#                   Age_Group Customer_Gender         Country             State  \
# 60993        Adults (35-64)               M   United States        California
# ...

# %%
df[df.duplicated()]
# Out:
#             Date   Day_Name  Day     Month  Year  Customer_Age  \
# 69019 2011-02-20     Sunday   20  February  2011            25
# 58238 2011-03-03   Thursday    3     March  2011            43
# 63341 2011-03-24   Thursday   24     March  2011            24
# 59240 2011-06-11   Saturday   11      June  2011            42
# 59821 2011-06-27     Monday   27      June  2011            37
# ...          ...        ...  ...       ...   ...           ...
# 12268 2016-07-18     Monday   18      July  2016            68
# 74739 2016-07-20  Wednesday   20      July  2016            53
# 2979  2016-07-23   Saturday   23      July  2016            44
# 11140 2016-07-29     Friday   29      July  2016            55
# 76826 2016-07-30   Saturday   30      July  2016            33
#
#                   Age_Group Customer_Gender        Country             State  \
# 69019  Young Adults (25-34)               F         Canada  British Columbia
# ...

# %%
df = df.drop_duplicates().reset_index()
df
# Out:
#         index       Date  Day_Name  Day    Month  Year  Customer_Age  \
# 0       60993 2011-01-01  Saturday    1  January  2011            42
# 1       58729 2011-01-01  Saturday    1  January  2011            33
# 2       58913 2011-01-01  Saturday    1  January  2011            17
# 3       63711 2011-01-01  Saturday    1  January  2011            39
# 4       49787 2011-01-01  Saturday    1  January  2011            23
# ...       ...        ...       ...  ...      ...   ...           ...
# 112031  22465 2016-07-31    Sunday   31     July  2016            39
# 112032  23363 2016-07-31    Sunday   31     July  2016            39
# 112033  19225 2016-07-31    Sunday   31     July  2016            48
# 112034  94147 2016-07-31    Sunday   31     July  2016            51
# 112035  80944 2016-07-31    Sunday   31     July  2016            42
#
#                    Age_Group Customer_Gender         Country  \
# 0             Adults (35-64)               M   United States
# ...

# %%
df.set_index('index', inplace=True)
df
# Out:
#             Date  Day_Name  Day    Month  Year  Customer_Age  \
# index
# 60993 2011-01-01  Saturday    1  January  2011            42
# 58729 2011-01-01  Saturday    1  January  2011            33
# 58913 2011-01-01  Saturday    1  January  2011            17
# 63711 2011-01-01  Saturday    1  January  2011            39
# 49787 2011-01-01  Saturday    1  January  2011            23
# ...          ...       ...  ...      ...   ...           ...
# 22465 2016-07-31    Sunday   31     July  2016            39
# 23363 2016-07-31    Sunday   31     July  2016            39
# 19225 2016-07-31    Sunday   31     July  2016            48
# 94147 2016-07-31    Sunday   31     July  2016            51
# 80944 2016-07-31    Sunday   31     July  2016            42
#
#                   Age_Group Customer_Gender         Country             State  \
# index
# 60993        Adults (35-64)               M   United States        California
# ...

# %%
df.to_csv("Clean Data.csv", index=False)
